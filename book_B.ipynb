# %% [markdown]
# <div style="display: flex; background-color: RGB(255,114,0);" >
# <h1 style="margin: auto; padding: 30px; ">Brief - Analyse_librairie </h1>
# </div>

# %% [markdown]
# <div style="background-color: RGB(51,165,182);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Partie 1 - Librairies et fichiers csv</h2>
# </div>

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">1.1 - Importation des librairies</h3>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.set(style='whitegrid',
    context='notebook',
    palette='Paired',
    rc={'figure.figsize':(8,4)})

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">1.2 - Read the data file </h3>
# </div>

# %%
df_clients = pd.read_csv("clients.csv")
df_ventes = pd.read_csv("ventes.csv")
df_produits = pd.read_csv("produits.csv")

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 20px; color: RGB(51,165,182); ">1.2 - Data files opservation   </h3>
# </div>

# %%
df_clients
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %%
print("verification if there is some NaN:")
df_clients.isnull().sum()
# Out:
# verification if there is some NaN:
# client_id    0
# sex          0
# birth        0
# dtype: int64

# %%
df_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8623 entries, 0 to 8622
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  8623 non-null   object
#  1   sex        8623 non-null   object
#  2   birth      8623 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 202.2+ KB

# %%
print("verification if there is some duplicated lignes:")
df_clients.duplicated().sum()
# Out:
# verification if there is some duplicated lignes:
# 0

# %%
print("this data have ",len(df_clients), "lines presenting number of customers")
print("with ",df_clients.columns,"information.")
# Out:
# this data have  8623 lines presenting number of customers
# with  Index(['client_id', 'sex', 'birth'], dtype='object') information.

# %%
df_ventes
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [337016 rows x 4 columns]

# %%
print("verification if there is some duplicated lignes:")
df_ventes.duplicated().sum()
# Out:
# verification if there is some duplicated lignes:
# 126

# %%
print("verification if there is some NaN:")
df_ventes.isnull().sum()
# Out:
# verification if there is some NaN:
# id_prod       0
# date          0
# session_id    0
# client_id     0
# dtype: int64

# %%
df_ventes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337016 entries, 0 to 337015
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     337016 non-null  object
#  1   date        337016 non-null  object
#  2   session_id  337016 non-null  object
#  3   client_id   337016 non-null  object
# dtypes: object(4)
# memory usage: 10.3+ MB

# %%
print("the number of lines before delete the duplicates information",len(df_ventes))
df_ventes.drop_duplicates(inplace= True )
print("the number of lines before delete the duplicates information",len(df_ventes))
# Out:
# the number of lines before delete the duplicates information 337016
# the number of lines before delete the duplicates information 336890

# %%
df_produits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_prod  3287 non-null   object
#  1   price    3287 non-null   float64
#  2   categ    3287 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 77.2+ KB

# %%
print("verification if there is some NaN:")
# Out:
# verification if there is some NaN:

# %%
print("verification if there is some duplicated lignes:")

df_produits.duplicated().sum()
# Out:
# verification if there is some duplicated lignes:
# 0

# %%
print("the maximum price is :")
df_produits.price.max()
# Out:
# the maximum price is :
# 300.0

# %%
print("the minimum price is :")
df_produits.price.min()
# Out:
# the minimum price is :
# -1.0

# %%
#affichage du boxplot
plt.style.use('_mpl-gallery')
red_round = dict(markerfacecolor='r', marker='o')
fig, ax1 = plt.subplots(figsize=(8,5.5))
ax1.set_title('zscore Plot')
ax1.boxplot(df_produits.price, flierprops=red_round, vert=True, whis=2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19a4603ae20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19a464d94c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19a4603ab50>],
#  'medians': [<matplotlib.lines.Line2D at 0x19a464d99a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19a464d9c70>],
#  'means': []}

# %%
#Delete the negative prices 
df_produits = df_produits.drop(df_produits[df_produits.price<0].index)
df_produits.price.min()
# Out:
# 0.62

# %%
#merge all the data frame that we have to collecte the maximum of information 
df_v = pd.merge(df_ventes, df_produits)
df_v[["date"]].sort_values(by = "date")
# Out:
#                               date
# 207638  2021-03-01 00:01:07.843138
# 13728   2021-03-01 00:02:26.047414
# 201126  2021-03-01 00:02:38.311413
# 11321   2021-03-01 00:04:54.559692
# 72447   2021-03-01 00:05:18.801198
# ...                            ...
# 122484  2022-02-28 23:56:57.196281
# 96153   2022-02-28 23:56:57.561424
# 255737  2022-02-28 23:57:12.741573
# 58009   2022-02-28 23:59:02.381670
# 299560  2022-02-28 23:59:58.040472
#
# [336713 rows x 1 columns]

# %%
df = pd.merge(df_v, df_clients)
df
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450   4.99      0
# 1       0_1085  2021-09-29 11:14:59.793823    s_97382    c_4450   3.99      0
# 2       0_1453  2021-08-27 19:50:46.796939    s_81509    c_4450   7.99      0
# 3       0_1405  2021-08-27 20:07:25.878440    s_81509    c_4450   4.99      0
# 4       0_1392  2021-12-28 11:45:04.072281   s_141302    c_4450   6.30      0
# ...        ...                         ...        ...       ...    ...    ...
# 336708   1_607  2021-09-25 07:26:00.224331    s_95185    c_4786  26.99      1
# 336709   1_673  2021-06-01 00:49:49.781631    s_42350    c_2793  12.99      1
# 336710  0_2075  2021-10-09 09:03:48.268536   s_102200    c_2793   8.99      0
# 336711  0_1692  2021-09-15 19:42:08.596375    s_90430    c_4478  13.36      0
# 336712   0_142  2021-09-25 18:07:25.880052    s_95415    c_1232  19.85      0
#
#        sex  birth
# ...

# %%
#verification if our final data has some NaN 
print("verification if there is some NaN:")
df.isnull().sum()
# Out:
# verification if there is some NaN:
# id_prod       0
# date          0
# session_id    0
# client_id     0
# price         0
# categ         0
# sex           0
# birth         0
# dtype: int64

# %%
df = df.assign(age=0)
val =list(df.date)
for i in range(len(val)):
    val[i] = int(val[i][0:4]) 

df.age = val-df.birth
df
df.date = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %% [markdown]
# <div style="background-color: RGB(51,165,182);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Partie 2 - Analyse de données</h2>
# </div>

# %%
X_lorenz = np.array(df.price).cumsum() / np.array(df.price).sum()
X_lorenz = np.insert(X_lorenz, 0, 0) 
X_lorenz[0], X_lorenz[-1]
# Out:
# (0.0, 1.000000000003987)

# %%
plt.figure(figsize=[8,6])
dep = df.price
n = len(dep)
lorenz = np.cumsum(np.sort(dep)) / dep.sum()
lorenz = np.append([0],lorenz) # La courbe de Lorenz commence à 0

xaxis = np.linspace(0-1/n,1+1/n,n+1) #Il y a un segment de taille n pour chaque individu, plus 1 segment supplémentaire d'ordonnée 0. Le premier segment commence à 0-1/n, et le dernier termine à 1+1/n.
plt.plot([0,1], [0,1], color='k')

plt.plot(xaxis,lorenz)
plt.title("Courbe de lorenz des prix")
plt.show()

# %%
def gini(arr):
    ## first sort
    sorted_arr = np.array(arr.copy())
    sorted_arr.sort()
    n = arr.size
    coef_ = 2. / n
    const_ = (n + 1.) / n
    weighted_sum = sum([(i+1)*yi for i, yi in enumerate(sorted_arr)])
    return coef_*weighted_sum/(sorted_arr.sum()) - const_
print("indice de gini: ",gini(df.price))
# Out:
# indice de gini:  0.3921455108917651

# %%
df.price.describe(include='all')
# Out:
# count    336713.000000
# mean         17.215189
# std          17.855445
# min           0.620000
# 25%           8.610000
# 50%          13.900000
# 75%          18.990000
# max         300.000000
# Name: price, dtype: float64

# %%
df.age.describe()
# Out:
# count    336713.000000
# mean         43.351261
# std          13.532614
# min          17.000000
# 25%          34.000000
# 50%          42.000000
# 75%          51.000000
# max          93.000000
# Name: age, dtype: float64

# %%
corr_sex = df.groupby(by="sex").categ.value_counts().to_frame()
corr_sex.rename(columns={"categ":"nb_categ"}, inplace=True)
corr_sex.reset_index("categ", inplace = True)
corr_sex
# Out:
#      categ  nb_categ
# sex
# f        0    103786
# f        1     55469
# f        2      8260
# m        0    105640
# m        1     54266
# m        2      9292

# %%
r=np.corrcoef(np.array(corr_sex.categ),np.array(corr_sex.nb_categ))
r
# Out:
# array([[ 1.        , -0.99958347],
#        [-0.99958347,  1.        ]])

# %%
df['price_Binary'] = pd.cut(x = df['price'],
                     bins = [df['price'].min()-1,
                            df['price'].mean(),
                             df['price'].max()+1],
                     labels = ['cheap','expensive'])
df
# Out:
#        id_prod                       date session_id client_id  price  categ  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   4.99      0
# 1       0_1085 2021-09-29 11:14:59.793823    s_97382    c_4450   3.99      0
# 2       0_1453 2021-08-27 19:50:46.796939    s_81509    c_4450   7.99      0
# 3       0_1405 2021-08-27 20:07:25.878440    s_81509    c_4450   4.99      0
# 4       0_1392 2021-12-28 11:45:04.072281   s_141302    c_4450   6.30      0
# ...        ...                        ...        ...       ...    ...    ...
# 336708   1_607 2021-09-25 07:26:00.224331    s_95185    c_4786  26.99      1
# 336709   1_673 2021-06-01 00:49:49.781631    s_42350    c_2793  12.99      1
# 336710  0_2075 2021-10-09 09:03:48.268536   s_102200    c_2793   8.99      0
# 336711  0_1692 2021-09-15 19:42:08.596375    s_90430    c_4478  13.36      0
# 336712   0_142 2021-09-25 18:07:25.880052    s_95415    c_1232  19.85      0
#
#        sex  birth  age price_Binary
# ...

# %%
df['age_Binary'] = pd.cut(x = df['age'],
                     bins = [df['age'].min()-1,
                            df['age'].mean(),
                             df['age'].max()+1],
                     labels = ['yeang','old'])
df
# Out:
#        id_prod                       date session_id client_id  price  categ  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   4.99      0
# 1       0_1085 2021-09-29 11:14:59.793823    s_97382    c_4450   3.99      0
# 2       0_1453 2021-08-27 19:50:46.796939    s_81509    c_4450   7.99      0
# 3       0_1405 2021-08-27 20:07:25.878440    s_81509    c_4450   4.99      0
# 4       0_1392 2021-12-28 11:45:04.072281   s_141302    c_4450   6.30      0
# ...        ...                        ...        ...       ...    ...    ...
# 336708   1_607 2021-09-25 07:26:00.224331    s_95185    c_4786  26.99      1
# 336709   1_673 2021-06-01 00:49:49.781631    s_42350    c_2793  12.99      1
# 336710  0_2075 2021-10-09 09:03:48.268536   s_102200    c_2793   8.99      0
# 336711  0_1692 2021-09-15 19:42:08.596375    s_90430    c_4478  13.36      0
# 336712   0_142 2021-09-25 18:07:25.880052    s_95415    c_1232  19.85      0
#
# ...

# %% [markdown]
# Correlatttion

# %%
corr = df.corr()
plt.figure(figsize=[8,6])

sns.heatmap(corr,
            xticklabels = corr.columns,
            yticklabels = corr.columns,
            cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df, x='date', hue='categ', palette=["#cf6ba9", "#cd919e", "#800020"])
plt.xticks(rotation=45)
plt.title('Volume des ventes par date et catégorie')
#plt.savefig(url_fig + 'histogramme_date-categorie.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Distribution et moyenne des prix par catégorie
plt.figure(figsize=(8,3))
sns.boxplot(data=df, y='price', x='categ', orient='v', showfliers=False, showmeans=True, palette=["#ff00ff", "#ff0000", "#ff00ff"], meanprops={"marker":"*","markerfacecolor":"#ccff66"})
plt.title('Distribution des prix par catégorie')
#plt.savefig(url_fig + 'boxplots_prix-categorie.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Mois de la transaction
df['mois'] = pd.DatetimeIndex(df['date']).month 

df['date_fixe'] = df['date'].dt.date

df = df.merge(
    df.groupby('client_id').count()['date'].reset_index().rename(columns={'date': 'total_ventes'}),
    how='left', on='client_id')

df['ventes_mensuelles'] = round(df['total_ventes'] / 11)

df = df.merge(
    df.pivot_table(
        index=['client_id', 'date_fixe'], 
        values='price', 
        aggfunc='count').reset_index().pivot_table(
        index='client_id').reset_index().rename(
        columns={'price': 'taille_panier_moyen'}), 
    on='client_id', how='left')

df = df.merge(
    df.pivot_table(
        index=['client_id', 'date_fixe'], 
        values='price').reset_index().pivot_table(
        index='client_id').reset_index().rename(
        columns={'price': 'panier_moyen'}), 
    on='client_id', how='left').drop('date_fixe', axis=1)


df = df.merge(
    df.pivot_table(
    index='client_id', values='price', 
    aggfunc='sum').reset_index().rename(
    columns={'price': 'total_achats'}),
    on='client_id', how='left')

# %%
ca_annuel = df.pivot_table(
    index='client_id', values=[
        'total_achats','ventes_mensuelles','taille_panier_moyen','total_ventes','panier_moyen']
    ).sort_values(by='total_achats', ascending=False).reset_index()
ca_annuel
# Out:
#      client_id  panier_moyen  taille_panier_moyen  total_achats  total_ventes  \
# 0       c_1609     12.583255            35.219178     162007.34         12855
# 1       c_4958     56.409462             7.096953     144257.21          2562
# 2       c_6714     16.339640            12.665722      73197.34          4471
# 3       c_3454     16.199991             8.967123      54442.92          3273
# 4       c_7959     13.453490             2.746479       2564.25           195
# ...        ...           ...                  ...           ...           ...
# 8595    c_8351      6.310000             1.000000          6.31             1
# 8596     c_890      6.080000             1.000000          6.08             1
# 8597    c_1675      5.570000             1.000000          5.57             1
# 8598    c_8114      4.990000             1.000000          4.99             1
# 8599    c_8140      4.150000             1.000000          4.15             1
#
#       ventes_mensuelles
# ...

# %%
df
# Out:
#        id_prod                       date session_id client_id  price  categ  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   4.99      0
# 1       0_1085 2021-09-29 11:14:59.793823    s_97382    c_4450   3.99      0
# 2       0_1453 2021-08-27 19:50:46.796939    s_81509    c_4450   7.99      0
# 3       0_1405 2021-08-27 20:07:25.878440    s_81509    c_4450   4.99      0
# 4       0_1392 2021-12-28 11:45:04.072281   s_141302    c_4450   6.30      0
# ...        ...                        ...        ...       ...    ...    ...
# 336708   1_607 2021-09-25 07:26:00.224331    s_95185    c_4786  26.99      1
# 336709   1_673 2021-06-01 00:49:49.781631    s_42350    c_2793  12.99      1
# 336710  0_2075 2021-10-09 09:03:48.268536   s_102200    c_2793   8.99      0
# 336711  0_1692 2021-09-15 19:42:08.596375    s_90430    c_4478  13.36      0
# 336712   0_142 2021-09-25 18:07:25.880052    s_95415    c_1232  19.85      0
#
# ...

# %%
def lorenz(variable, title):
    plt.figure(figsize=(8,5))
    X = variable.values
    X = np.sort(X)
    
    # Indice de Gini
    def gini(array):
        array
        sorted_array = array.copy()
        sorted_array.sort()
        n = array.size
        coef_ = 2. / n
        const_ = (n + 1.) / n
        weighted_sum = sum([(i+1)*yi for i, yi in enumerate(sorted_array)])
        return coef_*weighted_sum/(sorted_array.sum()) - const_
    print('Incide de Gini :', gini(X))
    
    # Courbe de Lorenz
    X_lorenz = X.cumsum() / X.sum()
    X_lorenz = np.insert(X_lorenz, 0, 0)
    # X_lorenz[0], X_lorenz[-1]
    y = np.arange(X_lorenz.size)/(X_lorenz.size-1)
    lorenz = pd.DataFrame()
    lorenz['X'] = pd.Series(X_lorenz)
    lorenz['Y'] = pd.Series(y)
    sns.scatterplot(data=lorenz, x='Y', y='X', marker='x')

    # Diagonale
    a = np.arange(0,1,.01)
    x = a
    y = a
    
    # Graphique
    
    sns.lineplot(x=x,y=y)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.title(title)
    plt.show()
    
lorenz(ca_annuel['total_achats'], 'Courbe de lorenz des prix')
# Out:
# Incide de Gini : 0.4397099070275057

# %%
fig, axes = plt.subplots(1, 2)
fig.suptitle('Pyramide des âges par sexe')


sns.histplot(ax=axes[0], y=df[df['sex']=='m']['age'], bins=12)
axes[0].invert_xaxis()
axes[0].set_title('Hommes')

sns.histplot(ax=axes[1], y=df[df['sex']=='f']['age'], bins=12)
axes[1].set_yticklabels([])
axes[1].set_ylabel('')
axes[1].set_title('Femmes')

plt.subplots_adjust(wspace=0, hspace=0)
#plt.savefig(url_fig + 'pyramide_ages.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="categ",hue="sex", data=df, palette="Set1")
plt.title('Effectifs des ventes par sexe et catégorie')
# Out:
# Text(0.5, 1.0, 'Effectifs des ventes par sexe et catégorie')

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='date', hue='sex', binwidth=12, element='poly', palette = ['#FF00FF','#0099FF'])
plt.title('Volume des ventes par sexe et date d achat')
#plt.savefig(url_fig + 'histogramme_date-sexe.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap( df.corr(), vmin=-1, vmax=1, annot=True, cmap='magma_r')
heatmap.set_title('Heatmap Correlation', fontdict={'fontsize':16}, pad=16)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='age', showfliers=False)
plt.title('Distribution des âges')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df.sort_values(by='age'), y='price', x='age')
plt.title('Distribution des prix par classe d\'âge')
plt.show()

# %%
df["tran_age"]= pd.cut(df.age,[0,20,35,45,60,100])
df
# Out:
#        id_prod                       date session_id client_id  price  categ  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   4.99      0
# 1       0_1085 2021-09-29 11:14:59.793823    s_97382    c_4450   3.99      0
# 2       0_1453 2021-08-27 19:50:46.796939    s_81509    c_4450   7.99      0
# 3       0_1405 2021-08-27 20:07:25.878440    s_81509    c_4450   4.99      0
# 4       0_1392 2021-12-28 11:45:04.072281   s_141302    c_4450   6.30      0
# ...        ...                        ...        ...       ...    ...    ...
# 336708   1_607 2021-09-25 07:26:00.224331    s_95185    c_4786  26.99      1
# 336709   1_673 2021-06-01 00:49:49.781631    s_42350    c_2793  12.99      1
# 336710  0_2075 2021-10-09 09:03:48.268536   s_102200    c_2793   8.99      0
# 336711  0_1692 2021-09-15 19:42:08.596375    s_90430    c_4478  13.36      0
# 336712   0_142 2021-09-25 18:07:25.880052    s_95415    c_1232  19.85      0
#
# ...

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df.sort_values(by='age').sample(500), y='price', x='age')
plt.title('Distribution des prix par classe d\'âge')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df.sort_values(by='tran_age'), y='tran_age', x='price', showfliers=False)
plt.title('Distribution des prix par tranche d\'âge')
# Out:
# Text(0.5, 1.0, "Distribution des prix par tranche d'âge")

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df.sort_values(by='tran_age'), y='tran_age', x='total_achats', showfliers=False)
plt.title('Distribution des chiffres d\'affaires par tranche d\'âge')
# Out:
# Text(0.5, 1.0, "Distribution des chiffres d'affaires par tranche d'âge")

# %%
ddf = df.pivot_table(index=['client_id'])
ddf.sort_values("ventes_mensuelles", ascending=False)
ddf = ddf[ddf['ventes_mensuelles']<200]
ddf
# Out:
#                  age  birth     categ      mois  panier_moyen      price  \
# client_id
# c_1        66.050000   1955  0.300000  9.250000     13.627267  15.032500
# c_10       65.000000   1956  0.678571  7.750000     21.399156  20.935000
# c_100      29.000000   1992  0.833333  6.666667     36.678889  37.145000
# c_1000     55.250000   1966  0.642857  6.107143     16.945705  17.500357
# c_1001     39.155172   1982  0.275862  7.655172     15.833949  19.007759
# ...              ...    ...       ...       ...           ...        ...
# c_995      66.000000   1955  0.375000  6.875000     15.906000  14.885000
# c_996      51.095238   1970  0.595238  6.452381     17.246048  17.609524
# c_997      27.173913   1994  0.826087  7.043478     31.436167  24.908261
# c_998      20.142857   2001  1.285714  6.964286     67.085128  54.560357
# c_999      57.227273   1964  0.500000  7.727273     13.429048  13.863636
#
#            taille_panier_moyen  total_achats  total_ventes  ventes_mensuelles
# ...

# %%
plt.figure(figsize=(20,4))
sns.boxplot(data=ddf,  x=ddf.age.astype(int),
    y='ventes_mensuelles')
plt.xticks(rotation=90)
plt.title('Distribution des fréquences d\'achat, par âge')

plt.show()

# %%
plt.figure(figsize=(16,4))
sns.boxplot(data=ddf, y='taille_panier_moyen', x=ddf.age.astype(int), showfliers=False, showmeans=True)
plt.xticks(rotation=90)
plt.title('Distribution de la taille du panier moyen, par âge')
plt.show()

# %%
age_categ = df.groupby(by=["age","categ"], as_index = False).count()
age_categ = age_categ[["age","categ","id_prod"]]
age_categ.rename(columns = {"id_prod":"nb"}, inplace=True)

age_categ
# Out:
#      age  categ    nb
# 0     17      0  1396
# 1     17      1  2150
# 2     17      2  2381
# 3     18      0   682
# 4     18      1  1249
# ..   ...    ...   ...
# 223   92      0    35
# 224   92      1    49
# 225   92      2     1
# 226   93      0     6
# 227   93      1    17
#
# [228 rows x 3 columns]

# %%
age_categ.corr()
# Out:
#             age     categ       nb
# age    1.000000 -0.025806 -0.32188
# categ -0.025806  1.000000 -0.43301
# nb    -0.321880 -0.433010  1.00000
